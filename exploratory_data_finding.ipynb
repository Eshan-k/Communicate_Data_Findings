# %% [markdown]
# ## Project: Data Exploration of the performance of globally-selected 15/16-year-old students in Mathematics, Reading and Science Literacy, based on the results of the PISA 2012 test
#
# ### **by Eshan Kulkarni**

# %% [markdown]
# ## Introduction of the topic and dataset
#
# ### Introduction to PISA *(ref.: NCES 2014-024, U.S. Department of Education)*
#
# #### What Is PISA?
#
# The Program for International Student Assessment (PISA) is a system of international assessments that allows countries to compare outcomes of learning as students near the end of compulsory schooling. PISA core assessments measure the performance of 15-year-old students in mathematics, science, and reading literacy every 3 years. Coordinated by the Organization for Economic Cooperation and Development (OECD), PISA was first implemented in 2000 in 32 countries. It has since grown to 65 education systems in 2012.

# %% [markdown]
# #### What PISA Measures
#
# PISA’s goal is to assess students’ preparation for the challenges of life as young adults. PISA assesses the application of knowledge in mathematics, science, and reading literacy to problems within a reallife context (OECD 1999). PISA does not focus explicitly on curricular outcomes and uses the term “literacy” in each subject area to indicate its broad focus on the application of knowledge and skills. For example, when assessing mathematics, PISA examines how well 15-year-old students can understand, use, and reflect on mathematics for a variety of real-life problems and settings that they may not encounter in the classroom. Scores on the PISA scales represent skill levels along a continuum of literacy skills.
#
# Each PISA data collection cycle assesses one of the three core subject areas in depth (considered the major subject area), although all three core subjects are assessed in each cycle (the other two subjects are considered minor subject areas for that assessment year). Assessing all three subjects every 3 years allows countries to have a consistent source of achievement data in each of the three subjects, while rotating one area as the primary focus over the years. Mathematics was the major subject area in 2012, as it was in 2003, since each subject is a major subject area once every three cycles. In 2012, mathematics, science, and reading literacy were assessed primarily through a paper-and-pencil assessment, and problem solving was administered via a computer-based assessment. In addition to these core assessments, education systems could participate in optional paper-based financial literacy and computer-based mathematics and reading assessments. The United States participated in these optional assessments. Visit www.nces.ed.gov/surveys/pisa for more information on the PISA assessments, including information on how the assessments were designed and examples of PISA questions.

# %% [markdown]
# ### Introduction to the PISA 2012 dataset
#
# PISA is a survey of students' skills and knowledge as they approach the end of compulsory education. It is not a conventional school test. Rather than examining how well students have learned the school curriculum, it looks at how well prepared they are for life beyond school.
#
# Around 510,000 students in 65 economies took part in the PISA 2012 assessment of reading, mathematics and science representing about 28 million 15-year-olds globally. Of those economies, 44 took part in an assessment of creative problem solving and 18 in an assessment of financial literacy.
#
# ***

# %% [markdown]
# <a id='dataset_investigation'></a>
# ## Dataset Investigation and Preliminary Wrangling
#
# Since the dataset provided has _636_ variables (according to its specified data dictionary), we will begin our exploration by wrangling the data accordingly, in order to better understand which variables might be worth delving into.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

pd.set_option('display.max_rows', 636)
pd.set_option('display.max_columns', 636)

# %%
df = pd.read_csv('pisa2012.csv', encoding='latin-1', low_memory = False)

# %%
df.head()
# Out:
#    Unnamed: 0      CNT  SUBNATIO  STRATUM      OECD       NC  SCHOOLID  \
# 0           1  Albania     80000  ALB0006  Non-OECD  Albania         1
# 1           2  Albania     80000  ALB0006  Non-OECD  Albania         1
# 2           3  Albania     80000  ALB0006  Non-OECD  Albania         1
# 3           4  Albania     80000  ALB0006  Non-OECD  Albania         1
# 4           5  Albania     80000  ALB0006  Non-OECD  Albania         1
#
#    STIDSTD  ST01Q01  ST02Q01  ST03Q01  ST03Q02 ST04Q01  \
# 0        1       10      1.0        2     1996  Female
# 1        2       10      1.0        2     1996  Female
# 2        3        9      1.0        9     1996  Female
# 3        4        9      1.0        8     1996  Female
# 4        5        9      1.0       10     1996  Female
#
#                        ST05Q01  ST06Q01    ST07Q01    ST07Q02    ST07Q03  \
# 0                         No        6.0  No, never  No, never  No, never
# 1  Yes, for more than one year      7.0  No, never  No, never  No, never
# 2  Yes, for more than one year      6.0  No, never  No, never  No, never
# 3  Yes, for more than one year      6.0  No, never  No, never  No, never
# 4  Yes, for more than one year      6.0  No, never  No, never  No, never
#
#               ST08Q01 ST09Q01  ST115Q01 ST11Q01 ST11Q02 ST11Q03 ST11Q04  \
# 0              None    None         1.0     Yes     Yes     Yes     Yes
# 1  One or two times    None         1.0     Yes     Yes     NaN     Yes
# 2              None    None         1.0     Yes     Yes      No     Yes
# 3              None    None         1.0     Yes     Yes      No     Yes
# 4  One or two times    None         2.0     Yes     Yes     Yes     NaN
#
#   ST11Q05 ST11Q06                                ST13Q01 ST14Q01 ST14Q02  \
# 0     NaN     NaN                      <ISCED level 3A>       No      No
# 1     NaN     NaN                      <ISCED level 3A>      Yes     Yes
# 2      No      No                  <ISCED level 3B, 3C>      Yes     Yes
# 3      No      No                  <ISCED level 3B, 3C>       No      No
# 4     NaN     NaN  She did not complete <ISCED level 1>       No      No
#
#   ST14Q03 ST14Q04                             ST15Q01                ST17Q01  \
# 0      No      No  Other (e.g. home duties, retired)       <ISCED level 3A>
# 1      No      No        Working full-time <for pay>       <ISCED level 3A>
# 2     Yes      No        Working full-time <for pay>       <ISCED level 3A>
# 3      No      No        Working full-time <for pay>       <ISCED level 3A>
# 4      No      No         Working part-time <for pay>  <ISCED level 3B, 3C>
#
#   ST18Q01 ST18Q02 ST18Q03 ST18Q04                       ST19Q01  \
# 0     NaN     NaN     NaN     NaN   Working part-time <for pay>
# 1      No      No      No      No  Working full-time <for pay>
# 2     Yes      No     Yes     Yes  Working full-time <for pay>
# 3     Yes     Yes      No      No  Working full-time <for pay>
# 4      No      No      No     Yes   Working part-time <for pay>
#
#            ST20Q01          ST20Q02          ST20Q03  ST21Q01  \
# 0  Country of test  Country of test  Country of test      NaN
# 1  Country of test  Country of test  Country of test      NaN
# 2  Country of test  Country of test  Country of test      NaN
# 3  Country of test  Country of test  Country of test      NaN
# 4  Country of test  Country of test  Country of test      NaN
#
#                 ST25Q01 ST26Q01 ST26Q02 ST26Q03 ST26Q04 ST26Q05 ST26Q06  \
# 0  Language of the test     Yes      No     Yes      No      No      No
# 1  Language of the test     Yes     Yes     Yes     Yes     Yes     Yes
# 2  Language of the test     Yes     Yes     Yes     Yes      No     Yes
# 3  Language of the test     Yes     Yes     Yes     Yes     Yes     Yes
# 4  Language of the test     Yes     Yes      No     Yes     Yes     Yes
#
#   ST26Q07 ST26Q08 ST26Q09 ST26Q10 ST26Q11 ST26Q12 ST26Q13 ST26Q14  ST26Q15  \
# 0      No     Yes      No     Yes      No     Yes      No     Yes     8002
# 1     Yes     Yes     Yes     Yes     Yes     Yes     Yes     Yes     8001
# 2     Yes     Yes     Yes     Yes      No     Yes      No     Yes     8001
# 3     Yes     Yes     Yes     Yes      No     Yes     Yes      No     8001
# 4     Yes     Yes     Yes     Yes      No     Yes     Yes     Yes     8001
#
#    ST26Q16  ST26Q17        ST27Q01        ST27Q02        ST27Q03 ST27Q04  \
# 0     8001     8002            Two            One           None    None
# 1     8001     8002  Three or more  Three or more  Three or more     Two
# 2     8001     8001  Three or more            Two            Two     One
# 3     8001     8002  Three or more            Two            One    None
# 4     8002     8001            Two            One            Two    None
#
#   ST27Q05              ST28Q01   ST29Q01         ST29Q02   ST29Q03   ST29Q04  \
# 0    None          0-10 books      Agree  Strongly agree     Agree     Agree
# 1     Two       201-500 books   Disagree  Strongly agree  Disagree  Disagree
# 2     Two  More than 500 books     Agree  Strongly agree     Agree     Agree
# 3     One         11-25 books        NaN             NaN       NaN       NaN
# 4     One       101-200 books   Disagree  Strongly agree  Disagree  Disagree
#
#           ST29Q05         ST29Q06         ST29Q07         ST29Q08  \
# 0           Agree           Agree           Agree  Strongly agree
# 1           Agree           Agree        Disagree        Disagree
# 2  Strongly agree  Strongly agree  Strongly agree  Strongly agree
# 3             NaN             NaN             NaN             NaN
# 4  Strongly agree  Strongly agree  Strongly agree  Strongly agree
#
#           ST35Q01         ST35Q02         ST35Q03         ST35Q04  \
# 0        Disagree           Agree        Disagree           Agree
# 1  Strongly agree  Strongly agree        Disagree           Agree
# 2  Strongly agree  Strongly agree           Agree  Strongly agree
# 3             NaN             NaN             NaN             NaN
# 4  Strongly agree  Strongly agree  Strongly agree  Strongly agree
#
#           ST35Q05 ST35Q06               ST37Q01             ST37Q02  \
# 0           Agree   Agree  Not at all confident  Not very confident
# 1        Disagree   Agree             Confident      Very confident
# 2  Strongly agree   Agree             Confident      Very confident
# 3             NaN     NaN                   NaN                 NaN
# 4  Strongly agree   Agree             Confident      Very confident
#
#           ST37Q03         ST37Q04         ST37Q05               ST37Q06  \
# 0       Confident       Confident       Confident  Not at all confident
# 1  Very confident       Confident  Very confident             Confident
# 2  Very confident       Confident  Very confident    Not very confident
# 3             NaN             NaN             NaN                   NaN
# 4             NaN  Very confident  Very confident             Confident
#
#           ST37Q07             ST37Q08         ST42Q01         ST42Q02  \
# 0       Confident      Very confident           Agree        Disagree
# 1  Very confident  Not very confident             NaN             NaN
# 2  Very confident           Confident             NaN             NaN
# 3             NaN                 NaN             NaN  Strongly agree
# 4  Very confident  Not very confident  Strongly agree  Strongly agree
#
#     ST42Q03         ST42Q04         ST42Q05   ST42Q06         ST42Q07  \
# 0     Agree           Agree           Agree     Agree           Agree
# 1       NaN             NaN             NaN       NaN             NaN
# 2       NaN             NaN             NaN       NaN             NaN
# 3  Disagree           Agree           Agree  Disagree  Strongly agree
# 4     Agree  Strongly agree  Strongly agree  Disagree        Disagree
#
#     ST42Q08   ST42Q09   ST42Q10         ST43Q01         ST43Q02  \
# 0  Disagree  Disagree  Disagree           Agree        Disagree
# 1       NaN       NaN       NaN  Strongly agree  Strongly agree
# 2       NaN       NaN       NaN  Strongly agree           Agree
# 3  Disagree     Agree     Agree             NaN             NaN
# 4  Disagree     Agree     Agree  Strongly agree  Strongly agree
#
#              ST43Q03            ST43Q04         ST43Q05            ST43Q06  \
# 0           Disagree              Agree             NaN           Disagree
# 1  Strongly disagree           Disagree           Agree           Disagree
# 2     Strongly agree  Strongly disagree  Strongly agree  Strongly disagree
# 3                NaN                NaN             NaN                NaN
# 4           Disagree           Disagree  Strongly agree           Disagree
#
#   ST44Q01          ST44Q03          ST44Q04        ST44Q05          ST44Q07  \
# 0  Likely  Slightly likely           Likely         Likely           Likely
# 1  Likely  Slightly likely  Slightly likely  Very   Likely  Slightly likely
# 2  Likely           Likely    Very   Likely  Very   Likely    Very   Likely
# 3     NaN              NaN              NaN            NaN              NaN
# 4  Likely           Likely           Likely         Likely  Slightly likely
#
#            ST44Q08         ST46Q01         ST46Q02         ST46Q03  \
# 0    Very   Likely           Agree           Agree           Agree
# 1           Likely           Agree           Agree  Strongly agree
# 2  Slightly likely  Strongly agree  Strongly agree  Strongly agree
# 3              NaN             NaN             NaN             NaN
# 4    Very   Likely  Strongly agree  Strongly agree           Agree
#
#           ST46Q04         ST46Q05 ST46Q06         ST46Q07         ST46Q08  \
# 0           Agree           Agree   Agree           Agree           Agree
# 1  Strongly agree  Strongly agree   Agree           Agree        Disagree
# 2  Strongly agree  Strongly agree   Agree  Strongly agree  Strongly agree
# 3             NaN             NaN     NaN             NaN             NaN
# 4  Strongly agree  Strongly agree   Agree  Strongly agree  Strongly agree
#
#           ST46Q09                             ST48Q01  \
# 0           Agree  Courses after school Test Language
# 1           Agree           Courses after school Math
# 2  Strongly agree           Courses after school Math
# 3             NaN                                 NaN
# 4  Strongly agree  Courses after school Test Language
#
#                     ST48Q02                     ST48Q03  \
# 0  Major in college Science  Study harder Test Language
# 1  Major in college Science           Study harder Math
# 2  Major in college Science           Study harder Math
# 3                       NaN                         NaN
# 4     Major in college Math           Study harder Math
#
#                    ST48Q04                    ST48Q05  \
# 0  Maximum classes Science     Pursuing a career Math
# 1  Maximum classes Science  Pursuing a career Science
# 2  Maximum classes Science  Pursuing a career Science
# 3                      NaN                        NaN
# 4     Maximum classes Math     Pursuing a career Math
#
#                    ST49Q01                  ST49Q02                  ST49Q03  \
# 0                    Often                Sometimes                Sometimes
# 1                Sometimes                    Often  Always or almost always
# 2                Sometimes  Always or almost always                Sometimes
# 3                      NaN                      NaN                      NaN
# 4  Always or almost always  Always or almost always                    Often
#
#            ST49Q04                  ST49Q05          ST49Q06          ST49Q07  \
# 0        Sometimes                Sometimes  Never or rarely  Never or rarely
# 1        Sometimes  Always or almost always  Never or rarely  Never or rarely
# 2  Never or rarely  Always or almost always  Never or rarely  Never or rarely
# 3              NaN                      NaN              NaN              NaN
# 4            Often                Sometimes              NaN        Sometimes
#
#            ST49Q09            ST53Q01                ST53Q02         ST53Q03  \
# 0  Never or rarely                NaN                    NaN             NaN
# 1            Often  relating to known  Improve understanding     in my sleep
# 2  Never or rarely     Most important  Improve understanding  learning goals
# 3              NaN  relating to known               new ways  learning goals
# 4        Sometimes                NaN                    NaN             NaN
#
#             ST53Q04                                            ST55Q01  \
# 0               NaN                                                NaN
# 1   Repeat examples  I do not attend <out-of-school time lessons> i...
# 2  more information                           Less than 2 hours a week
# 3  more information  I do not attend <out-of-school time lessons> i...
# 4               NaN                                                NaN
#
#                                              ST55Q02  \
# 0                                                NaN
# 1             2 or more but less than 4 hours a week
# 2             2 or more but less than 4 hours a week
# 3  I do not attend <out-of-school time lessons> i...
# 4                                                NaN
#
#                                   ST55Q03  \
# 0                                     NaN
# 1  2 or more but less than 4 hours a week
# 2  4 or more but less than 6 hours a week
# 3                Less than 2 hours a week
# 4                                     NaN
#
#                                              ST55Q04  ST57Q01  ST57Q02  \
# 0                                                NaN      NaN      NaN
# 1                           Less than 2 hours a week      NaN      NaN
# 2  I do not attend <out-of-school time lessons> i...      NaN      6.0
# 3  I do not attend <out-of-school time lessons> i...     10.0      2.0
# 4                                                NaN      NaN      NaN
#
#    ST57Q03  ST57Q04  ST57Q05  ST57Q06     ST61Q01    ST61Q02     ST61Q03  \
# 0      NaN      NaN      NaN      NaN         NaN        NaN         NaN
# 1      6.0      0.0      0.0      2.0     Rarely     Rarely   Frequently
# 2      6.0      7.0      2.0      3.0  Frequently  Sometimes  Frequently
# 3      2.0      0.0      0.0      3.0   Sometimes  Sometimes   Sometimes
# 4      NaN      NaN      NaN      NaN         NaN        NaN         NaN
#
#      ST61Q04     ST61Q05    ST61Q06     ST61Q07    ST61Q08     ST61Q09  \
# 0        NaN         NaN        NaN         NaN        NaN         NaN
# 1  Sometimes  Frequently  Sometimes  Frequently     Never   Frequently
# 2    Rarely   Frequently    Rarely   Frequently  Sometimes  Frequently
# 3  Sometimes  Frequently  Sometimes  Frequently    Rarely   Frequently
# 4        NaN         NaN        NaN         NaN        NaN         NaN
#
#                                  ST62Q01  \
# 0                                    NaN
# 1  Know it well,  understand the concept
# 2                      Never heard of it
# 3                      Heard of it often
# 4                                    NaN
#
#                                  ST62Q02                    ST62Q03  \
# 0                                    NaN                        NaN
# 1  Know it well,  understand the concept  Heard of it once or twice
# 2  Know it well,  understand the concept  Heard of it once or twice
# 3                      Heard of it often          Heard of it often
# 4                                    NaN                        NaN
#
#                                  ST62Q04  \
# 0                                    NaN
# 1  Know it well,  understand the concept
# 2  Know it well,  understand the concept
# 3  Know it well,  understand the concept
# 4                                    NaN
#
#                                  ST62Q06  \
# 0                                    NaN
# 1  Know it well,  understand the concept
# 2  Know it well,  understand the concept
# 3                Heard of it a few times
# 4                                    NaN
#
#                                  ST62Q07                    ST62Q08  \
# 0                                    NaN                        NaN
# 1  Know it well,  understand the concept          Never heard of it
# 2  Know it well,  understand the concept  Heard of it once or twice
# 3  Know it well,  understand the concept          Never heard of it
# 4                                    NaN                        NaN
#
#                                  ST62Q09  \
# 0                                    NaN
# 1  Know it well,  understand the concept
# 2  Know it well,  understand the concept
# 3  Know it well,  understand the concept
# 4                                    NaN
#
#                                  ST62Q10                    ST62Q11  \
# 0                                    NaN                        NaN
# 1  Know it well,  understand the concept          Never heard of it
# 2  Know it well,  understand the concept  Heard of it once or twice
# 3  Know it well,  understand the concept          Never heard of it
# 4                                    NaN                        NaN
#
#                                  ST62Q12  \
# 0                                    NaN
# 1  Know it well,  understand the concept
# 2  Know it well,  understand the concept
# 3  Know it well,  understand the concept
# 4                                    NaN
#
#                                  ST62Q13  \
# 0                                    NaN
# 1              Heard of it once or twice
# 2  Know it well,  understand the concept
# 3                      Never heard of it
# 4                                    NaN
#
#                                  ST62Q15  \
# 0                                    NaN
# 1  Know it well,  understand the concept
# 2  Know it well,  understand the concept
# 3  Know it well,  understand the concept
# 4                                    NaN
#
#                                  ST62Q16  \
# 0                                    NaN
# 1  Know it well,  understand the concept
# 2  Know it well,  understand the concept
# 3  Know it well,  understand the concept
# 4                                    NaN
#
#                                  ST62Q17  \
# 0                                    NaN
# 1                      Never heard of it
# 2  Know it well,  understand the concept
# 3                      Heard of it often
# 4                                    NaN
#
#                                  ST62Q19  ST69Q01  ST69Q02  ST69Q03  ST70Q01  \
# 0                                    NaN      NaN      NaN      NaN      NaN
# 1                      Heard of it often     45.0     45.0     45.0      7.0
# 2  Know it well,  understand the concept     60.0      NaN      NaN      5.0
# 3                      Heard of it often     45.0     45.0     45.0      3.0
# 4                                    NaN      NaN      NaN      NaN      NaN
#
#    ST70Q02  ST70Q03  ST71Q01  ST72Q01     ST73Q01     ST73Q02     ST74Q01  \
# 0      NaN      NaN      NaN      NaN         NaN         NaN         NaN
# 1      6.0      2.0      NaN     30.0  Frequently   Sometimes  Frequently
# 2      4.0      2.0     24.0     30.0  Frequently  Frequently  Frequently
# 3      3.0      2.0      NaN     28.0  Frequently   Sometimes  Frequently
# 4      NaN      NaN      NaN      NaN         NaN         NaN         NaN
#
#       ST74Q02     ST75Q01     ST75Q02    ST76Q01    ST76Q02       ST77Q01  \
# 0         NaN         NaN         NaN        NaN        NaN  Every Lesson
# 1  Frequently   Sometimes   Sometimes  Sometimes  Sometimes           NaN
# 2  Frequently  Frequently  Frequently    Rarely     Rarely            NaN
# 3     Rarely   Frequently  Frequently  Sometimes  Sometimes  Every Lesson
# 4         NaN         NaN         NaN        NaN        NaN  Every Lesson
#
#         ST77Q02       ST77Q04       ST77Q05       ST77Q06  \
# 0  Every Lesson  Every Lesson  Every Lesson  Every Lesson
# 1           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN
# 3  Every Lesson  Every Lesson  Every Lesson  Every Lesson
# 4  Most Lessons  Every Lesson  Most Lessons  Some Lessons
#
#                 ST79Q01       ST79Q02               ST79Q03       ST79Q04  \
# 0  Never or Hardly Ever  Most Lessons  Never or Hardly Ever  Every Lesson
# 1                   NaN           NaN                   NaN           NaN
# 2                   NaN           NaN                   NaN           NaN
# 3                   NaN  Every Lesson          Every Lesson  Every Lesson
# 4          Some Lessons  Some Lessons          Most Lessons  Some Lessons
#
#         ST79Q05       ST79Q06       ST79Q07       ST79Q08  \
# 0  Most Lessons  Every Lesson  Every Lesson  Every Lesson
# 1           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN
# 3  Every Lesson  Every Lesson  Every Lesson  Every Lesson
# 4  Most Lessons  Every Lesson  Most Lessons  Every Lesson
#
#                 ST79Q10               ST79Q11       ST79Q12       ST79Q15  \
# 0  Never or Hardly Ever          Most Lessons  Every Lesson  Every Lesson
# 1                   NaN                   NaN           NaN           NaN
# 2                   NaN                   NaN           NaN           NaN
# 3          Every Lesson  Never or Hardly Ever  Most Lessons  Every Lesson
# 4          Some Lessons          Most Lessons  Most Lessons  Every Lesson
#
#         ST79Q17                  ST80Q01    ST80Q04          ST80Q05  \
# 0  Every Lesson  Always or almost always  Sometimes  Never or rarely
# 1           NaN                      NaN        NaN              NaN
# 2           NaN                      NaN        NaN              NaN
# 3  Every Lesson  Always or almost always        NaN              NaN
# 4  Most Lessons  Always or almost always      Often        Sometimes
#
#                    ST80Q06                  ST80Q07                  ST80Q08  \
# 0  Always or almost always  Always or almost always  Always or almost always
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                    Often                    Often                    Often
#
#                    ST80Q09 ST80Q10          ST80Q11               ST81Q01  \
# 0  Always or almost always   Often            Often  Never or Hardly Ever
# 1                      NaN     NaN              NaN                   NaN
# 2                      NaN     NaN              NaN                   NaN
# 3                      NaN     NaN  Never or rarely  Never or Hardly Ever
# 4  Always or almost always   Often            Often          Some Lessons
#
#                 ST81Q02               ST81Q03               ST81Q04  \
# 0  Never or Hardly Ever  Never or Hardly Ever  Never or Hardly Ever
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3  Never or Hardly Ever  Never or Hardly Ever  Never or Hardly Ever
# 4          Some Lessons                   NaN          Most Lessons
#
#                 ST81Q05            ST82Q01            ST82Q02  \
# 0  Never or Hardly Ever  Strongly disagree  Strongly disagree
# 1                   NaN                NaN                NaN
# 2                   NaN                NaN                NaN
# 3                   NaN                NaN                NaN
# 4  Never or Hardly Ever  Strongly disagree           Disagree
#
#              ST82Q03            ST83Q01         ST83Q02         ST83Q03  \
# 0  Strongly disagree  Strongly disagree           Agree           Agree
# 1                NaN                NaN             NaN             NaN
# 2                NaN                NaN             NaN             NaN
# 3     Strongly agree     Strongly agree  Strongly agree  Strongly agree
# 4     Strongly agree     Strongly agree           Agree  Strongly agree
#
#   ST83Q04         ST84Q01         ST84Q02   ST84Q03 ST85Q01  \
# 0   Agree  Strongly agree  Strongly agree  Disagree   Agree
# 1     NaN             NaN             NaN       NaN     NaN
# 2     NaN             NaN             NaN       NaN     NaN
# 3     NaN             NaN             NaN       NaN     NaN
# 4   Agree        Disagree  Strongly agree  Disagree   Agree
#
#              ST85Q02         ST85Q03 ST85Q04 ST86Q01            ST86Q02  \
# 0  Strongly disagree        Disagree   Agree   Agree  Strongly disagree
# 1                NaN             NaN     NaN     NaN                NaN
# 1  probably not do this    probably do this    probably not do this
# 2  probably not do this  definitely do this  definitely not do this
# 3                   NaN                 NaN                     NaN
# 4    definitely do this  definitely do this      definitely do this
#
#               ST96Q05  ST101Q01  ST101Q02  ST101Q03  ST101Q05  ST104Q01  \
# 0  definitely do this       4.0       2.0       1.0       1.0       1.0
# 1    probably do this       1.0       2.0       3.0       2.0       2.0
# 2    probably do this       1.0       3.0       4.0       1.0       3.0
# 3                 NaN       NaN       NaN       NaN       NaN       NaN
# 4  definitely do this       1.0       2.0       1.0       2.0       1.0
#
#    ST104Q04  ST104Q05  ST104Q06 IC01Q01 IC01Q02 IC01Q03 IC01Q04 IC01Q05  \
# 0       2.0       1.0       1.0     NaN     NaN     NaN     NaN     NaN
# 1       3.0       1.0       1.0     NaN     NaN     NaN     NaN     NaN
# 2       4.0       1.0       1.0     NaN     NaN     NaN     NaN     NaN
# 3       NaN       NaN       NaN     NaN     NaN     NaN     NaN     NaN
# 4       2.0       1.0       1.0     NaN     NaN     NaN     NaN     NaN
#
#   IC01Q06 IC01Q07 IC01Q08 IC01Q09 IC01Q10 IC01Q11 IC02Q01 IC02Q02 IC02Q03  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#   IC02Q04 IC02Q05 IC02Q06 IC02Q07 IC03Q01 IC04Q01  IC05Q01  IC06Q01  IC07Q01  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN       99       99       99
# 1     NaN     NaN     NaN     NaN     NaN     NaN       99       99       99
# 2     NaN     NaN     NaN     NaN     NaN     NaN       99       99       99
# 3     NaN     NaN     NaN     NaN     NaN     NaN       99       99       99
# 4     NaN     NaN     NaN     NaN     NaN     NaN       99       99       99
#
#   IC08Q01 IC08Q02 IC08Q03 IC08Q04 IC08Q05 IC08Q06 IC08Q07 IC08Q08 IC08Q09  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#   IC08Q11 IC09Q01 IC09Q02 IC09Q03 IC09Q04 IC09Q05 IC09Q06 IC09Q07 IC10Q01  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#   IC10Q02 IC10Q03 IC10Q04 IC10Q05 IC10Q06 IC10Q07 IC10Q08 IC10Q09 IC11Q01  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#   IC11Q02 IC11Q03 IC11Q04 IC11Q05 IC11Q06 IC11Q07 IC22Q01 IC22Q02 IC22Q04  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#   IC22Q06 IC22Q07 IC22Q08 EC01Q01 EC02Q01 EC03Q01 EC03Q02 EC03Q03 EC03Q04  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#   EC03Q05 EC03Q06 EC03Q07 EC03Q08 EC03Q09 EC03Q10  EC04Q01A  EC04Q01B  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN       NaN       NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN       NaN       NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN       NaN       NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN       NaN       NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN       NaN       NaN
#
#    EC04Q01C  EC04Q02A  EC04Q02B  EC04Q02C  EC04Q03A  EC04Q03B  EC04Q03C  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#    EC04Q04A  EC04Q04B  EC04Q04C  EC04Q05A  EC04Q05B  EC04Q05C  EC04Q06A  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#    EC04Q06B  EC04Q06C EC05Q01 EC06Q01 EC07Q01 EC07Q02 EC07Q03 EC07Q04 EC07Q05  \
# 0       NaN       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1       NaN       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2       NaN       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3       NaN       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4       NaN       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#   EC08Q01 EC08Q02 EC08Q03 EC08Q04 EC09Q03 EC10Q01 EC11Q02 EC11Q03 EC12Q01  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#   ST22Q01 ST23Q01 ST23Q02 ST23Q03 ST23Q04 ST23Q05 ST23Q06 ST23Q07 ST23Q08  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#   ST24Q01 ST24Q02 ST24Q03              CLCUSE1  CLCUSE301  CLCUSE302  DEFFORT  \
# 0     NaN     NaN     NaN  A Simple calculator         99         99       99
# 1     NaN     NaN     NaN  A Simple calculator         99         99       99
# 2     NaN     NaN     NaN  A Simple calculator         99         99       99
# 3     NaN     NaN     NaN                  NaN         99         99       99
# 4     NaN     NaN     NaN                  NaN         99         99       99
#
#       QUESTID     BOOKID                      EASY    AGE  GRADE  \
# 0  StQ Form B  booklet 7  Standard set of booklets  16.17    0.0
# 1  StQ Form A  booklet 9  Standard set of booklets  16.17    0.0
# 2  StQ Form A  booklet 3  Standard set of booklets  15.58   -1.0
# 3  StQ Form C  booklet 2  Standard set of booklets  15.67   -1.0
# 4  StQ Form B  booklet 4  Standard set of booklets  15.50   -1.0
#
#                                 PROGN  ANXMAT  ATSCHL  ATTLNACT  BELONG  \
# 0  Albania: Upper secondary education    0.32   -2.31    0.5206   -1.18
# 1  Albania: Upper secondary education     NaN     NaN       NaN     NaN
# 2  Albania: Lower secondary education     NaN     NaN       NaN     NaN
# 3  Albania: Lower secondary education    0.31     NaN       NaN     NaN
# 4  Albania: Lower secondary education    1.02    1.38    1.2115    2.63
#
#    BFMJ2  BMMJ1  CLSMAN   COBN_F   COBN_M   COBN_S  COGACT  CULTDIST  CULTPOS  \
# 0  76.49  79.74 -1.3771  Albania  Albania  Albania  0.6994       NaN    -0.48
# 1  15.35  23.47     NaN  Albania  Albania  Albania     NaN       NaN     1.27
# 2  22.57    NaN     NaN  Albania  Albania  Albania     NaN       NaN     1.27
# 3  14.21    NaN     NaN  Albania  Albania  Albania -0.3788       NaN     1.27
# 4  80.92    NaN -0.0784  Albania  Albania  Albania  0.5403       NaN     1.27
#
#    DISCLIMA  ENTUSE  ESCS  EXAPPLM  EXPUREM  FAILMAT  FAMCON  FAMCONC  \
# 0      1.85     NaN   NaN      NaN      NaN   0.6400     NaN      NaN
# 1       NaN     NaN   NaN  -0.0681   0.7955   0.1524  0.6387    -0.08
# 2       NaN     NaN   NaN   0.5359   0.7955   1.2219  0.8215    -0.89
# 3      1.80     NaN   NaN   0.3220   0.7955      NaN  0.7266     0.24
# 4     -0.08     NaN   NaN      NaN      NaN   0.6400     NaN      NaN
#
#    FAMSTRUC             FISCED  HEDRES  HERITCUL             HISCED  HISEI  \
# 0       2.0  ISCED 3A, ISCED 4   -1.29       NaN  ISCED 3A, ISCED 4    NaN
# 1       2.0  ISCED 3A, ISCED 4    1.12       NaN        ISCED 5A, 6    NaN
# 2       2.0        ISCED 5A, 6   -0.69       NaN        ISCED 5A, 6    NaN
# 3       2.0        ISCED 5A, 6    0.04       NaN        ISCED 5A, 6    NaN
# 4       2.0  ISCED 3A, ISCED 4   -0.69       NaN  ISCED 3A, ISCED 4    NaN
#
#    HOMEPOS  HOMSCH  HOSTCUL  ICTATTNEG  ICTATTPOS  ICTHOME  ICTRES  ICTSCH  \
# 0    -2.61     NaN      NaN        NaN        NaN      NaN   -3.16     NaN
# 1     1.41     NaN      NaN        NaN        NaN      NaN    1.15     NaN
# 2     0.14     NaN      NaN        NaN        NaN      NaN   -0.40     NaN
# 3    -0.73     NaN      NaN        NaN        NaN      NaN   -0.40     NaN
# 4    -0.57     NaN      NaN        NaN        NaN      NaN    0.24     NaN
#
#     IMMIG  INFOCAR  INFOJOB1  INFOJOB2  INSTMOT  INTMAT ISCEDD         ISCEDL  \
# 0  Native      NaN       NaN       NaN     0.80    0.91      A  ISCED level 3
# 1  Native      NaN       NaN       NaN    -0.39    0.00      A  ISCED level 3
# 2  Native      NaN       NaN       NaN     1.59    1.23      A  ISCED level 2
# 3  Native      NaN       NaN       NaN      NaN     NaN      A  ISCED level 2
# 4  Native      NaN       NaN       NaN     1.59    0.30      A  ISCED level 2
#
#     ISCEDO  LANGCOMM      LANGN  LANGRPPD  LMINS  MATBEH  MATHEFF  MATINTFC  \
# 0  General       NaN  Albanian        NaN    NaN  0.6426    -0.77   -0.7332
# 1  General       NaN  Albanian        NaN  315.0  1.4702     0.34   -0.2514
# 2  General       NaN  Albanian        NaN  300.0  0.9618     0.34   -0.2514
# 3  General       NaN  Albanian        NaN  135.0     NaN      NaN       NaN
# 4  General       NaN  Albanian        NaN    NaN  1.8169     0.41    0.6584
#
#    MATWKETH             MISCED  MMINS   MTSUP  \
# 0    0.2882  ISCED 3A, ISCED 4    NaN -0.9508
# 1    0.6490        ISCED 5A, 6  270.0     NaN
# 2    2.0389        ISCED 5A, 6    NaN     NaN
# 3       NaN        ISCED 3B, C  135.0  1.6748
# 4    1.6881               None    NaN  0.6709
#
#                                         OCOD1  \
# 0                         Building architects
# 1  Tailors, dressmakers, furriers and hatters
# 2                                   Housewife
# 3                                   Housewife
# 4                                   Housewife
#
#                                                OCOD2  OPENPS  OUTHOURS  PARED  \
# 0                            Primary school teachers  0.0521       NaN   12.0
# 1                    Building construction labourers -0.9492       8.0   16.0
# 2                    Bricklayers and related workers  0.9383      24.0   16.0
# 3  Cleaners and helpers in offices, hotels and ot...     NaN      17.0   16.0
# 4                                         Economists  1.2387       NaN   12.0
#
#    PERSEV                    REPEAT  SCMAT  SMINS  STUDREL  SUBNORM  TCHBEHFA  \
# 0 -0.3407  Did not repeat a <grade>   0.41    NaN    -1.04  -0.0455    1.3625
# 1  1.3116  Did not repeat a <grade>    NaN   90.0      NaN   0.6602       NaN
# 2  0.9918  Did not repeat a <grade>    NaN    NaN      NaN   2.2350       NaN
# 3     NaN  Did not repeat a <grade>   0.18   90.0      NaN      NaN    0.7644
# 4  1.0819  Did not repeat a <grade>  -0.06    NaN    -0.02   2.8039    0.7644
#
#    TCHBEHSO  TCHBEHTD  TEACHSUP   TESTLANG  TIMEINT  USEMATH  USESCH  WEALTH  \
# 0    0.9374    0.4297      1.68  Albanian       NaN      NaN     NaN   -2.92
# 1       NaN       NaN       NaN  Albanian       NaN      NaN     NaN    0.69
# 1   13.9235   13.1249   13.1249    4.3389   13.0829    4.5084    4.5315
# 2   12.7307   12.7307   12.7307    4.2436   12.7307    4.2436    4.2436
# 3   12.7307   12.7307   12.7307    4.2436   12.7307    4.2436    4.2436
# 4   12.7307   12.7307   12.7307    4.2436   12.7307    4.2436    4.2436
#
#    W_FSTR63  W_FSTR64  W_FSTR65  W_FSTR66  W_FSTR67  W_FSTR68  W_FSTR69  \
# 0   13.0829    4.5315    4.3313    4.5084    4.5084   13.7954   13.9235
# 1   13.0829    4.5315    4.3313    4.5084    4.5084   13.7954   13.9235
# 2   12.7307    4.2436    4.2436    4.2436    4.2436   12.7307   12.7307
# 3   12.7307    4.2436    4.2436    4.2436    4.2436   12.7307   12.7307
# 4   12.7307    4.2436    4.2436    4.2436    4.2436   12.7307   12.7307
#
#    W_FSTR70  W_FSTR71  W_FSTR72  W_FSTR73  W_FSTR74  W_FSTR75  W_FSTR76  \
# 0    4.3389   13.0829   13.9235    4.3389    4.3313   13.7954   13.9235
# 1    4.3389   13.0829   13.9235    4.3389    4.3313   13.7954   13.9235
# 2    4.2436   12.7307   12.7307    4.2436    4.2436   12.7307   12.7307
# 3    4.2436   12.7307   12.7307    4.2436    4.2436   12.7307   12.7307
# 4    4.2436   12.7307   12.7307    4.2436    4.2436   12.7307   12.7307
#
#    W_FSTR77  W_FSTR78  W_FSTR79  W_FSTR80  WVARSTRR  VAR_UNIT  SENWGT_STU  \
# 0   13.1249   13.1249    4.3389   13.0829        19         1      0.2098
# 1   13.1249   13.1249    4.3389   13.0829        19         1      0.2098
# 2   12.7307   12.7307    4.2436   12.7307        19         1      0.1999
# 3   12.7307   12.7307    4.2436   12.7307        19         1      0.1999
# 4   12.7307   12.7307    4.2436   12.7307        19         1      0.1999
#
#    VER_STU
# 0  22NOV13
# 1  22NOV13
# 2  22NOV13
# 3  22NOV13
# 4  22NOV13

# %%
df = df[['CNT', 'ST03Q02', 'ST04Q01', 'AGE', 'PV1MATH', 'PV2MATH', 'PV3MATH', 'PV4MATH', 'PV5MATH', 'PV1READ', 
'PV2READ', 'PV3READ', 'PV4READ', 'PV5READ', 'PV1SCIE', 'PV2SCIE', 'PV3SCIE', 'PV4SCIE', 'PV5SCIE', 'COBN_F', 'COBN_M', 'COBN_S']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 485490 entries, 0 to 485489
# Data columns (total 22 columns):
# CNT        485490 non-null object
# ST03Q02    485490 non-null int64
# ST04Q01    485490 non-null object
# AGE        485374 non-null float64
# PV1MATH    485490 non-null float64
# PV2MATH    485490 non-null float64
# PV3MATH    485490 non-null float64
# PV4MATH    485490 non-null float64
# PV5MATH    485490 non-null float64
# PV1READ    485490 non-null float64
# PV2READ    485490 non-null float64
# PV3READ    485490 non-null float64
# PV4READ    485490 non-null float64
# PV5READ    485490 non-null float64
# PV1SCIE    485490 non-null float64
# PV2SCIE    485490 non-null float64
# PV3SCIE    485490 non-null float64
# PV4SCIE    485490 non-null float64
# PV5SCIE    485490 non-null float64
# COBN_F     481825 non-null object
# COBN_M     481843 non-null object
# COBN_S     481836 non-null object
# dtypes: float64(16), int64(1), object(5)
# memory usage: 81.5+ MB

# %%
df.head()
# Out:
#        CNT  ST03Q02 ST04Q01    AGE   PV1MATH   PV2MATH   PV3MATH   PV4MATH  \
# 0  Albania     1996  Female  16.17  406.8469  376.4683  344.5319  321.1637
# 1  Albania     1996  Female  16.17  486.1427  464.3325  453.4273  472.9008
# 2  Albania     1996  Female  15.58  533.2684  481.0796  489.6479  490.4269
# 3  Albania     1996  Female  15.67  412.2215  498.6836  415.3373  466.7472
# 4  Albania     1996  Female  15.50  381.9209  328.1742  403.7311  418.5309
#
#     PV5MATH   PV1READ   PV2READ   PV3READ   PV4READ   PV5READ   PV1SCIE  \
# 0  381.9209  249.5762  254.3420  406.8496  175.7053  218.5981  341.7009
# 1  476.0165  406.2936  349.8975  400.7334  369.7553  396.7618  548.9929
# 2  533.2684  401.2100  404.3872  387.7067  431.3938  401.2100  499.6643
# 3  454.2842  547.3630  481.4353  461.5776  425.0393  471.9036  438.6796
# 4  395.1628  311.7707  141.7883  293.5015  272.8495  260.1405  361.5628
#
#     PV2SCIE   PV3SCIE   PV4SCIE   PV5SCIE   COBN_F   COBN_M   COBN_S
# 0  408.8400  348.2283  367.8105  392.9877  Albania  Albania  Albania
# 1  471.5964  471.5964  443.6218  454.8116  Albania  Albania  Albania
# 2  428.7952  492.2044  512.7191  499.6643  Albania  Albania  Albania
# 3  481.5740  448.9370  474.1141  426.5573  Albania  Albania  Albania
# 4  275.7740  372.7527  403.5248  422.1746  Albania  Albania  Albania

# %% [markdown]
# <h5> As we can see there some missing values </h5>

# %%
# replace missing values in age with mean value of age
df.loc[np.isfinite(df['AGE']) == False, 'AGE'] = df['AGE'].mean()

# %%
# replace NaN or invalid field with 'Missing'
df.loc[df['COBN_F'].isna() == True, 'COBN_F'] = 'Missing'
df.loc[df['COBN_M'].isna() == True, 'COBN_M'] = 'Missing'
df.loc[df['COBN_S'].isna() == True, 'COBN_S'] = 'Missing'

df.loc[df['COBN_M'] == 'Invalid', 'COBN_M'] = 'Missing'
df.loc[df['COBN_F'] == 'Invalid', 'COBN_M'] = 'Missing'
df.loc[df['COBN_S'] == 'Invalid', 'COBN_M'] = 'Missing'

# %%
# calculate the average score for Math, Reading & Science

df['Math Score'] = (df['PV1MATH'] + df['PV2MATH'] + df['PV3MATH'] + df['PV4MATH'] + df['PV5MATH']) / 5
df['Reading Score'] = (df['PV1READ'] + df['PV2READ'] + df['PV3READ'] + df['PV4READ'] + df['PV5READ']) / 5
df['Science Score'] = (df['PV1SCIE'] + df['PV2SCIE'] + df['PV3SCIE'] + df['PV4SCIE'] + df['PV5SCIE']) / 5

# %%
# drop unneccesary columns
df.drop(columns = ['PV1MATH', 'PV2MATH', 'PV3MATH', 'PV4MATH', 'PV5MATH', 'PV1READ', 'PV2READ', 'PV3READ', 
                   'PV4READ', 'PV5READ', 'PV1SCIE', 'PV2SCIE', 'PV3SCIE', 'PV4SCIE', 'PV5SCIE'], inplace=True)

# %%
# Rename columns
df.rename({'CNT' : 'Country', 'ST03Q02' : 'Birth year', 'ST04Q01' : 'Gender', 'AGE' : 'Age', 'COBN_F' : 'Birth Country Father', 
           'COBN_M' : 'Birth Country Mother', 'COBN_S' : 'Birth Country Child'}, axis = 'columns', inplace = True)

# %%
df['Same Culture Background'] = (df['Birth Country Father'] == df['Birth Country Mother'])

# %%
df.loc[df['Same Culture Background'] == True, 'Same Culture Background'] = 'Same'
df.loc[df['Same Culture Background'] == False, 'Same Culture Background'] = 'Different'

# %%
df.head()
# Out:
#    Country  Birth year  Gender    Age Birth Country Father  \
# 0  Albania        1996  Female  16.17              Albania
# 1  Albania        1996  Female  16.17              Albania
# 2  Albania        1996  Female  15.58              Albania
# 3  Albania        1996  Female  15.67              Albania
# 4  Albania        1996  Female  15.50              Albania
#
#   Birth Country Mother Birth Country Child  Math Score  Reading Score  \
# 0              Albania             Albania   366.18634      261.01424
# 1              Albania             Albania   470.56396      384.68832
# 2              Albania             Albania   505.53824      405.18154
# 3              Albania             Albania   449.45476      477.46376
# 4              Albania             Albania   385.50398      256.01010
#
#    Science Score Same Culture Background
# 0      371.91348                    Same
# 1      478.12382                    Same
# 2      486.60946                    Same
# 3      453.97240                    Same
# 4      367.15778                    Same

# %%
df.describe()
# Out:
#           Birth year            Age     Math Score  Reading Score  \
# count  485490.000000  485490.000000  485490.000000  485490.000000
# mean     1996.070061      15.784283     469.651234     472.006964
# std         0.255250       0.290186     100.786610      98.863310
# min      1996.000000      15.170000      54.767080       6.445400
# 25%      1996.000000      15.580000     396.019620     405.044200
# 50%      1996.000000      15.750000     465.734520     475.477980
# 75%      1996.000000      16.000000     540.123060     542.831195
# max      1997.000000      16.330000     903.107960     849.359740
#
#        Science Score
# count  485490.000000
# mean      475.808094
# std        97.998470
# min        25.158540
# 25%       405.762800
# 50%       475.512860
# 75%       546.381920
# max       857.832900

# %% [markdown]
# As we can see above, the data is clearly very abundant, with a large number of variables to take into consideration.
#
# *After looking throughout the Dataset, we will try to find answers to following questions:*
#
# * **_How do students from difeerent gender perform in Math, Reading and Science literacy?_**
#
# * **_Which countries have students with exceptionally high literacy scores?_**
#
# * **_We would like to find out whether students whose parents have different cultural backgrounds will report any changes in average scores, compared with students raised in a homogenous family background._**

# %% [markdown]
# <a id='univariate'></a>
# <h1> Univariant Analysis & Visualization </h1>

# %% [markdown]
# <h3> Math, Science, Reading Score Distribution across Students </h3>

# %%
plt.figure(figsize=[15, 5])
hist_bins = np.arange(0, 1000 + 1, 100)

# math score
plt.subplot(1, 3, 1);
plt.hist(df['Math Score'], bins=hist_bins, ec = 'black', alpha = 0.85);

plt.xlim(0, 1000);
plt.xticks(hist_bins)
plt.ylim(0, 180000 + 1);
plt.xlabel('Math Score');
plt.ylabel('Count of Students');
plt.title("Math Score Distribution");

# reading score
plt.subplot(1, 3, 2);
plt.hist(df['Reading Score'], bins=hist_bins, ec = 'black', alpha = 0.85);

plt.xlim(0, 1000);
plt.xticks(hist_bins)
plt.ylim(0, 180000 + 1);
plt.xlabel('Reading Score');
plt.ylabel('Count of Students');
plt.title("Reading Score Distribution");

# science score
plt.subplot(1, 3, 3);
plt.hist(df['Science Score'], bins=hist_bins, ec = 'black', alpha = 0.85);

plt.xlim(0, 1000);
plt.xticks(hist_bins)
plt.ylim(0, 180000 + 1);
plt.xlabel('Science Score');
plt.ylabel('Count of Students');
plt.title("Science Score Distribution");

# %% [markdown]
# <li> For the above distribution, most of the student scores are in the range of 400-500 points </li>
# <li> Majority of student score points are from 300-600 points </li>

# %% [markdown]
# <h3> Gender Distribution Across Students </h3>

# %%
plt.figure(figsize=[3, 5]);
sns.countplot(x = 'Gender', data = df, color = sns.color_palette()[0]);

y_ticks = np.arange(0, 450000 + 1, 50000)
plt.yticks(y_ticks, y_ticks);
plt.ylabel("Count of students");
plt.title('Gender distribution');

# %% [markdown]
# <li> The Gender ratio in the Dataset is almost equally distributed </li>

# %% [markdown]
# <h3> Countries having 'Exceptionally Performing' Students </h3>

# %%
math_score = df[df['Math Score'] > 800]['Country'].value_counts()
reading_score = df[df['Reading Score'] > 800]['Country'].value_counts()
science_score = df[df['Science Score'] > 800]['Country'].value_counts()

# %%
plt.figure(figsize = [15, 5])
plt.subplots_adjust(wspace = 0.6)
x_lim_max = math_score.values[0] + 6

plt.subplot(1, 3, 1)
sns.barplot(y = math_score.index, x = math_score.values, color = sns.color_palette()[0])
plt.title('Students with Math score > 800');
plt.xlabel('Count of students');
plt.ylabel('Countries');

plt.subplot(1, 3, 2)
sns.barplot(y = reading_score.index, x = reading_score.values, color = sns.color_palette()[0])
plt.xlim(0, x_lim_max);
plt.title('Students with Reading score > 800');
plt.xlabel('Count of students');
plt.ylabel('Countries');

plt.subplot(1, 3, 3)
sns.barplot(y = science_score.index, x = science_score.values, color = sns.color_palette()[0])
plt.xlim(0, x_lim_max);
plt.title('Students with Science score > 800');
plt.xlabel('Count of students');
plt.ylabel('Countries');

# %% [markdown]
# <li> China-Shanghai have the most students who have expectinally high math score </li>
# <li> Singapore has the most students who have expectinally high reading & sciece score </li>

# %% [markdown]
# <h3> Count of Parents with Same Culture Background </h3>

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x='Same Culture Background', data=df);
plt.show();

# %% [markdown]
# <li> Parent with Same Culture Background are significantly more than parent with different culture background </li>

# %% [markdown]
# <a id='bivariate'></a>
# <h1> Bivariant Analysis & Visualization </h1>

# %% [markdown]
# <h3> Gender wise - Score Distribution </h3>

# %%
plt.figure(figsize = [15, 4])
plt.subplots_adjust(wspace = 1.2)

plt.subplot(1, 3, 1)
sns.boxplot(x = df['Gender'], y = df['Math Score'], palette = 'Set2')
plt.title('Gender wise - Math scores');

plt.subplot(1, 3, 2)
sns.boxplot(x = df['Gender'], y = df['Reading Score'], palette = 'Set2')
plt.title('Gender Wise - Reading scores');

plt.subplot(1, 3, 3)
sns.boxplot(x = df['Gender'], y = df['Science Score'], palette = 'Set2');
plt.title('Gender wise - Science scores');

# %% [markdown]
# <li> It can be seen that Male student perform slightly better than Female students in Math </li>
# <li> It can be seen that Female student perform slightly better than Male students in Reading </li>
# <li> It can be seen that Male student & female students performance is same in Science </li>

# %% [markdown]
# <h3> Students scoring above 800, Country wise. </h3>

# %%
math_score = df[(df['Math Score'] >= 850)]['Country'].value_counts()
science_score = df[(df['Science Score'] >= 800)]['Country'].value_counts()
reading_score = df[(df['Reading Score'] >= 800)]['Country'].value_counts()

plt.figure(figsize = [15, 5])
plt.subplots_adjust(wspace = 0.6)
x_lim_max = science_score.values[0]

plt.subplot(1, 3, 1)
sns.barplot(y = math_score.index, x = math_score.values, color = sns.color_palette()[0])
plt.title('Students with Math scores > 850');
plt.xticks(np.arange(0, x_lim_max + 2, 1));

plt.subplot(1, 3, 2)
sns.barplot(y = science_score.index, x = science_score.values, color = sns.color_palette()[0])
plt.title('Students with Science scores > 800');
plt.xticks(np.arange(0, x_lim_max + 2, 1));

plt.subplot(1, 3, 3)
sns.barplot(y = reading_score.index, x = reading_score.values, color = sns.color_palette()[0])
plt.title('Students with Reading scores > 800');
plt.xticks(np.arange(0, x_lim_max + 2, 1));

# %% [markdown]
# <li> China-Shanghai have more students score more than 850 in Math </li>
# <li> Singapore have more students score more than 800 in Science & Reading </li>

# %% [markdown]
# <h3> Distribution of scores according to Culture Background </h3>

# %%
plt.figure(figsize = [15, 5])
plt.subplots_adjust(wspace = 1.2)

plt.subplot(1, 3, 1)
sns.boxplot(x = df['Same Culture Background'], y = df['Math Score'], palette = 'Set2')
plt.title('Same Culture Background wise - Math scores');

plt.subplot(1, 3, 2)
sns.boxplot(x = df['Same Culture Background'], y = df['Reading Score'], palette = 'Set2')
plt.title('Same Culture Background Wise - Reading scores');

plt.subplot(1, 3, 3)
sns.boxplot(x = df['Same Culture Background'], y = df['Science Score'], palette = 'Set2');
plt.title('Same Culture Background wise - Science scores');

# %% [markdown]
# It can be seen that, students coming from heterogenic family backgrounds report increased performance in all areas, compared to students from homogenous family backgrounds.

# %% [markdown]
# <a id='multivariate'></a>
# <h1> Multivariant Analysis & Visualization </h1>

# %% [markdown]
# <h3> Pair-by-pair representation of different scores </h3>

# %%
grid = sns.pairplot(data = df, vars=["Math Score", "Reading Score", "Science Score"]);
grid.fig.suptitle("Pair-by-pair representation of different scores' correlation", y = 1.02);

# %% [markdown]
# There is a very strong and positive correlation between any pair of the three variables representing the scores of the three subjects.

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions and answers
#
# * **_How do students from difeerent gender perform in Math, Reading and Science literacy?_**
# *_We have performed the analysis of particular question. The results can be explored in Visualisation 5 of Bivariant analysis_*
#
# * **_Which countries have students with exceptionally high literacy scores?_**
# *_Generally, we have seen Asian countries as being the world leaders at educating students who perform exceptionally. Singapore and China are examples of this._*
#
# * **_We would like to find out whether students whose parents have different cultural backgrounds will report any changes in average scores, compared with students raised in a homogenous family background._**
# *_We found that students whose parent come from different culture background tend perform better than students whose parents are from same culture background_*
